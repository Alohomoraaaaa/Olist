# %%
import getpass
password = getpass.getpass("Enter PostgreSQL password: ")
# Out:
# Enter PostgreSQL password:  ········

# %%
from sqlalchemy import create_engine

engine = create_engine(
    f"postgresql://postgres:{password}@localhost:5432/olist"
)

# %%
engine.connect()

# %%
import pandas as pd

customers = pd.read_csv("../dataset/clean/customers.csv")
geo = pd.read_csv("../dataset/clean/geo.csv")
items = pd.read_csv("../dataset/clean/items.csv")
payments = pd.read_csv("../dataset/clean/payments.csv")
reviews = pd.read_csv("../dataset/clean/reviews.csv")
orders = pd.read_csv("../dataset/clean/orders.csv")
products = pd.read_csv("../dataset/clean/products.csv")
sellers = pd.read_csv("../dataset/clean/sellers.csv")
category = pd.read_csv("../dataset/clean/category.csv")

# %%
tables = {
    "customers": customers,
    "geo": geo,
    "items": items,
    "payments": payments,
    "reviews": reviews,
    "orders": orders,
    "products": products,
    "sellers": sellers,
    "category": category
}

for name, df in tables.items():
    df.to_sql(name, engine, if_exists='replace', index=False)
    print(f"{name} uploaded")
# Out:
# customers uploaded
# geo uploaded
# items uploaded
# payments uploaded
# reviews uploaded
# orders uploaded
# products uploaded
# sellers uploaded
# category uploaded
